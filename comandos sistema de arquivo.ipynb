# %%
# %fs help
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

# %%
# %fs ls /
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
dbutils.fs.ls("/")
# Out:
# Out[2]: [FileInfo(path='dbfs:/FileStore/', name='FileStore/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-results/', name='databricks-results/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/user/', name='user/', size=0, modificationTime=0)]

# %%
# %fs mkdirs vendas
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = true
# </div>

# %%
# %fs ls /FileStore/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/</td><td>tables/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs cp /FileStore/tables/carga/vinhos_no_mundo.csv/FileStore/vendas2/copia_vinhos.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
dbutils.fs.cp("/FileStore/tables/carga/vinhos_no_mundo.csv", "/FileStore/vendas3/copia2_vinhos.csv")
# Out:
# Out[9]: True

# %%
mv /FileStore/vendas2/copia_vinhos.csv/FileStore/vendas2/copia_muda_vinhos.csv
# Out:
# mv: missing destination file operand after '/FileStore/vendas2/copia_vinhos.csv/FileStore/vendas2/copia_muda_vinhos.csv'
# Try 'mv --help' for more information.

# %%
dbutils.fs.mv("/FileStore/vendas2/copia_muda_vinhos.csv","/FileStore/vendas2/copia_troca_vinhos.csv")

# %%
# %fs rm /FileStore/vendas3/copia2_vinhos.csv
ou
dbutils.fs.rm("/FileStore/vendas3/copia2_vinhos.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
rm -r /FileStore/vendas2/Oudbutils.fs.rm("/FileStore/vendas2/", recurse=True)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `rm -r /FileStore/vendas2/Oudbutils.fs.rm("/FileStore/vendas2/", recurse=True) '

# %%
# %fs rm -r /FileStore/vendas2/Oudbutils.fs.rm("/FileStore/vendas2/", recurse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %%bash
# find /databricks -name "*.csv" | grep "fa"
# Out:
# /databricks/python3/lib/python3.8/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_Si0.csv
# /databricks/python3/lib/python3.8/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_beta.csv
# /databricks/python3/lib/python3.8/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_vi0.csv
# /databricks/python3/lib/python3.8/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_state_variates.csv
# /databricks/python3/lib/python3.8/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_Omega_22.csv
# /databricks/python3/lib/python3.8/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_posterior_mean.csv
# /databricks/python3/lib/python3.8/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_S10.csv
# /databricks/python3/lib/python3.8/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_v10.csv
# ...
